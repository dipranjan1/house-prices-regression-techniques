# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
import matplotlib.pyplot as plt

# %%
ds = pd.read_csv("train.csv")

# %%
ds
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
features = ["GrLivArea", "BedroomAbvGr", "FullBath"]

# %%
x = ds[features]

# %%
y = ds[features]

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
msc = mean_squared_error(y_test, y_pred)

# %%
r2 = r2_score(y_test, y_pred)

# %%
print("Mean Square Error:", msc)
print("R-squared:" ,r2)
# Out:
# Mean Square Error: 6.223368370869002e-25
# R-squared: 1.0

# %%
# plotting predictions analytics actual values
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual Prices vs Predicted Prices")
plt.show()

# %% [markdown]
# # P

# %%
import pandas as pd

# Create new input data
new_data = pd.DataFrame({'GrLivArea': [2000], 'BedroomAbvGr': [1], 'FullBath': [2]})

# Predict the price using the trained model
predicted_price = model.predict(new_data)

# Convert the first value of the NumPy array to a scalar
print("Predicted Price:", predicted_price[0])
# Out:
# Predicted Price: [2.e+03 1.e+00 2.e+00]

# %%
import pandas as pd

# Create new input data
new_data = pd.DataFrame({'GrLivArea': [2000], 'BedroomAbvGr': [1], 'FullBath': [2]})

# Predict the price using the trained model
predicted_price = model.predict(new_data)

# Print number of bedrooms, bathrooms, and predicted price
print(f"Number of Bedrooms: {new_data['BedroomAbvGr'][0]}")
print(f"Number of Bathrooms: {new_data['FullBath'][0]}")
print(f"Predicted Price: {predicted_price[0]}")
# Out:
# Number of Bedrooms: 1
# Number of Bathrooms: 2
# Predicted Price: [2.e+03 1.e+00 2.e+00]
